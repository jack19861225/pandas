# %% [markdown]
# ### Data Loading

# %%
import pandas

# %%
sephora_df = pandas.read_table('sephora.txt', header=0, names=['PROD', 'DOWNLOAD_DATE', 'PRICE'])

# %%
sephora_df
# Out:
#       PROD  DOWNLOAD_DATE PRICE
# 0   152747       20130806   $95
# 1   152747       20130813   $95
# 2   152747       20130820   $95
# 3   152751       20130730   $95
# 4   152751       20130806   $95
# 5   152751       20130813   $95
# 6   152751       20130820   $95
# 7   152762       20130730  $125
# 8   152762       20130806  $125
# 9   152762       20130813  $125
# 10  152762       20130820  $125
# 11  154353       20130730   $95
# 12  154353       20130806   $95
# 13  154353       20130813   $95
# 14  154353       20130820   $95
# 15  154387       20130730   $75
# 16  154387       20130806   $75
# 17  154387       20130813   $75
# 18  154387       20130820   $75
# 19  208600       20130730   $85
# 20  208600       20130806   $85
# 21  208600       20130813   $85
# 22  208600       20130820   $85
# 23  208601       20130730   $85
# 24  208602       20130730   $85
# 25  208602       20130806   $85
# 26  208602       20130813   $85
# 27  208602       20130820   $85
# ...

# %%
pandas.read_table('sephora.txt', header=0, names=['PROD', 'DOWNLOAD_DATE', 'PRICE'], index_col=['DOWNLOAD_DATE'])
# Out:
#                  PROD PRICE
# DOWNLOAD_DATE
# 20130806       152747   $95
# 20130813       152747   $95
# 20130820       152747   $95
# 20130730       152751   $95
# 20130806       152751   $95
# 20130813       152751   $95
# 20130820       152751   $95
# 20130730       152762  $125
# 20130806       152762  $125
# 20130813       152762  $125
# 20130820       152762  $125
# 20130730       154353   $95
# 20130806       154353   $95
# 20130813       154353   $95
# 20130820       154353   $95
# 20130730       154387   $75
# 20130806       154387   $75
# 20130813       154387   $75
# 20130820       154387   $75
# 20130730       208600   $85
# 20130806       208600   $85
# 20130813       208600   $85
# 20130820       208600   $85
# 20130730       208601   $85
# 20130730       208602   $85
# 20130806       208602   $85
# 20130813       208602   $85
# 20130820       208602   $85
# 20130730       208604  $195
# 20130806       208604  $195
# 20130813       208604  $195
# ...
